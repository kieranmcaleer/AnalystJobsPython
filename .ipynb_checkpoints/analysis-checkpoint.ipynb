# %%
#bring the data in
import pandas as pd
import numpy as np
import seaborn as sns
import re
import matplotlib.pyplot as plt
job_df = pd.read_csv('archive/DataAnalyst.csv')

# %%
#filter out the data that is not needed
job_df = job_df[job_df['Job Title'].str.contains('Data')]
job_df = job_df[job_df['Job Title'].str.contains('Analyst')]

# %%
#all rows contain data analyst now we can start breaking down the jobs according to what how many times they mention or if they mention a specific language
added_df = job_df[job_df['Job Description'].str.contains("tableau" ,na=False, flags=re.IGNORECASE)]
added_df
count_row = added_df.shape[0]
count_row
# Out:
# 616

# %%
#SQL
added_df["sql"] = added_df['Job Description'].str.contains("sql" ,na=False, flags=re.IGNORECASE)
#Python
added_df["python"] = added_df['Job Description'].str.contains("python" ,na=False, flags=re.IGNORECASE)
#R
added_df["sql"] = added_df['Job Description'].str.contains("sql" ,na=False, flags=re.IGNORECASE)
#Excel
added_df["excel"] = added_df['Job Description'].str.contains("excel" ,na=False, flags=re.IGNORECASE)
#Tableau
added_df["tableau"] = added_df['Job Description'].str.contains("tableau" ,na=False, flags=re.IGNORECASE)
#PowerBI
added_df["powerbi"] = added_df['Job Description'].str.contains("powerbi" ,na=False, flags=re.IGNORECASE)
#Machine Learning or ML
added_df["ml"] = added_df['Job Description'].str.contains("ml" or "machine learning" ,na=False, flags=re.IGNORECASE)
#Jupyter
added_df["jupyter"] = added_df['Job Description'].str.contains("jupyter" ,na=False, flags=re.IGNORECASE)
#Spark
added_df["spark"] = added_df['Job Description'].str.contains("spark" ,na=False, flags=re.IGNORECASE)
# Out:
# C:\Users\Kieran\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Kieran\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Kieran\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#checking to see if all of the columns have the same format
a_list = added_df['Salary Estimate'].tolist()

# %%
added_df
# Out:
#       Unnamed: 0                                          Job Title  \
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 11            11                                       Data Analyst
# 16            16                                       Data Analyst
# 21            21                               Data Science Analyst
# ...          ...                                                ...
# 2217        2217                         Technical Data Analyst - X
# 2227        2227                       Data Base Programmer/Analyst
# 2228        2228                       Senior Business/Data Analyst
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 11     $37K-$66K (Glassdoor est.)
# ...

# %%
# s.apply(lambda x: sum(x) / len(x))
added_df["Salary Estimate mean"] = added_df["Salary Estimate"].str.findall(r'\d+').explode().astype(int).groupby(level=0).mean()
# def get_numbers(x):
# list_series = added_df["Salary Estimate"].str.findall(r'\d+')
# for index, value in list_series.items():
#     for i in value:
#         i = int(i)       
# from statistics import mean
# added_df['Average Salary'] = added_df['Salary Estimate'].map(mean)


        
        


    

#     return list_series

# added_df["Average Salary"] = added_df["Salary Estimate"].apply(get_numbers)
# Out:
# C:\Users\Kieran\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
added_df
# Out:
#       Unnamed: 0                                          Job Title  \
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 11            11                                       Data Analyst
# 16            16                                       Data Analyst
# 21            21                               Data Science Analyst
# ...          ...                                                ...
# 2217        2217                         Technical Data Analyst - X
# 2227        2227                       Data Base Programmer/Analyst
# 2228        2228                       Senior Business/Data Analyst
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 11     $37K-$66K (Glassdoor est.)
# ...

# %%
selected_df = added_df[["Age", "Sex"]]
sns.countplot(x="variable", hue="value", data=pd.melt(added_df))
